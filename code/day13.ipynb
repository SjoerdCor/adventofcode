# %%
with open("../data/day13.txt") as f:
    data = f.read().split("\n\n")

# %%
import re
import numpy as np

# Regex to extract numbers for Button A, Button B, and Prize
pattern = r"Button A: X\+(\d+), Y\+(\d+)\nButton B: X\+(\d+), Y\+(\d+)\nPrize: X=(\d+), Y=(\d+)"

# Parse the data
parsed_data = []
for entry in data:
    match = re.match(pattern, entry)
    if match:
        # Convert all matched groups to integers
        button_a_x, button_a_y, button_b_x, button_b_y, prize_x, prize_y = map(
            int, match.groups()
        )
        parsed_data.append(
            {
                "Button A": np.array((button_a_x, button_a_y)),
                "Button B": np.array((button_b_x, button_b_y)),
                "Prize": np.array((prize_x, prize_y)),
            }
        )
    else:
        raise ValueError("")
parsed_data
# Out:
# [{'Button A': array([85, 71]),
#   'Button B': array([21, 84]),
#   'Prize': array([ 9947, 13426])},
#  {'Button A': array([20, 62]),
#   'Button B': array([62, 27]),
#   'Prize': array([6092, 7618])},
#  {'Button A': array([64, 14]),
#   'Button B': array([20, 48]),
#   'Prize': array([9128, 5754])},
#  {'Button A': array([56, 12]),
#   'Button B': array([13, 49]),
#   'Prize': array([1136, 2092])},
#  {'Button A': array([76, 51]),
#   'Button B': array([37, 97]),
#   'Prize': array([ 5111, 10286])},
#  {'Button A': array([86, 24]),
#   'Button B': array([20, 22]),
#   'Prize': array([2154, 1734])},
#  {'Button A': array([87, 96]),
#   'Button B': array([89, 13]),
#   'Prize': array([10425,  8436])},
#  {'Button A': array([36, 35]),
#   'Button B': array([15, 88]),
#   'Prize': array([3270, 8612])},
#  {'Button A': array([46, 82]),
#   'Button B': array([93, 24]),
#   'Prize': array([8545, 3748])},
#  {'Button A': array([72, 21]),
#   'Button B': array([18, 60]),
#   'Prize': array([9494, 9626])},
#  {'Button A': array([81, 25]),
#   'Button B': array([80, 91]),
#   'Prize': array([10929,  9142])},
#  {'Button A': array([81, 18]),
#   'Button B': array([46, 67]),
#   'Prize': array([5003, 2588])},
#  {'Button A': array([71, 34]),
#   'Button B': array([22, 35]),
#   'Prize': array([7247, 5134])},
#  {'Button A': array([71, 12]),
#   'Button B': array([88, 86]),
#   'Prize': array([3459,  798])},
#  {'Button A': array([96, 50]),
#   'Button B': array([54, 86]),
#   'Prize': array([9456, 6314])},
#  {'Button A': array([49, 27]),
#   'Button B': array([13, 27]),
#   'Prize': array([4994, 2970])},
#  {'Button A': array([44, 15]),
#   'Button B': array([27, 40]),
#   'Prize': array([5928, 4115])},
#  {'Button A': array([25, 59]),
#   'Button B': array([60, 25]),
#   'Prize': array([16730,   332])},
#  {'Button A': array([65, 15]),
#   'Button B': array([12, 33]),
#   'Prize': array([12944,  2786])},
#  {'Button A': array([59, 57]),
#   'Button B': array([80, 15]),
#   'Prize': array([9585, 3405])},
#  {'Button A': array([66, 22]),
#   'Button B': array([13, 66]),
#   'Prize': array([1717, 4334])},
#  {'Button A': array([80, 81]),
#   'Button B': array([23, 96]),
#   'Prize': array([3227, 5376])},
#  {'Button A': array([15, 39]),
#   'Button B': array([73, 39]),
#   'Prize': array([15440,  7868])},
#  {'Button A': array([59, 22]),
#   'Button B': array([17, 44]),
#   'Prize': array([5609, 3146])},
#  {'Button A': array([46, 21]),
#   'Button B': array([11, 32]),
#   'Prize': array([ 4973, 14627])},
#  {'Button A': array([32, 64]),
#   'Button B': array([45, 14]),
#   'Prize': array([6683, 6178])},
#  {'Button A': array([28, 42]),
#   'Button B': array([88, 29]),
#   'Prize': array([9068, 5774])},
#  {'Button A': array([84, 63]),
#   'Button B': array([13, 31]),
#   'Prize': array([15406, 13732])},
#  {'Button A': array([32, 60]),
#   'Button B': array([47, 17]),
#   'Prize': array([12321, 19487])},
#  {'Button A': array([36, 19]),
#   'Button B': array([17, 34]),
#   'Prize': array([4005, 7269])},
#  {'Button A': array([46, 17]),
#   'Button B': array([54, 77]),
#   'Prize': array([2284, 2042])},
#  {'Button A': array([63, 26]),
#   'Button B': array([13, 38]),
#   'Prize': array([ 5021, 14566])},
#  {'Button A': array([27, 77]),
#   'Button B': array([68, 18]),
#   'Prize': array([6392, 6442])},
#  {'Button A': array([13, 52]),
#   'Button B': array([67, 31]),
#   'Prize': array([5103, 2637])},
#  {'Button A': array([55, 73]),
#   'Button B': array([80, 13]),
#   'Prize': array([8415, 1944])},
#  {'Button A': array([31, 62]),
#   'Button B': array([54, 29]),
#   'Prize': array([17003, 19155])},
#  {'Button A': array([53, 22]),
#   'Button B': array([46, 66]),
#   'Prize': array([3732, 4598])},
#  {'Button A': array([26, 57]),
#   'Button B': array([65, 31]),
#   'Prize': array([16058,  4996])},
#  {'Button A': array([19, 50]),
#   'Button B': array([96, 18]),
#   'Prize': array([1105, 2204])},
#  {'Button A': array([36, 83]),
#   'Button B': array([39, 16]),
#   'Prize': array([3477, 3951])},
#  {'Button A': array([48, 31]),
#   'Button B': array([14, 43]),
#   'Prize': array([18770, 10200])},
#  {'Button A': array([44, 12]),
#   'Button B': array([35, 81]),
#   'Prize': array([15232,  2192])},
#  {'Button A': array([24, 51]),
#   'Button B': array([57, 25]),
#   'Prize': array([18914,  8198])},
#  {'Button A': array([99, 18]),
#   'Button B': array([78, 85]),
#   'Prize': array([5712, 2809])},
#  {'Button A': array([48, 30]),
#   'Button B': array([24, 49]),
#   'Prize': array([5048, 9409])},
#  {'Button A': array([34, 85]),
#   'Button B': array([90, 14]),
#   'Prize': array([10194,  9238])},
#  {'Button A': array([25, 72]),
#   'Button B': array([26, 18]),
#   'Prize': array([2107, 5670])},
#  {'Button A': array([36, 53]),
#   'Button B': array([35, 14]),
#   'Prize': array([19164, 15240])},
#  {'Button A': array([62, 42]),
#   'Button B': array([16, 77]),
#   'Prize': array([2350, 6951])},
#  {'Button A': array([52, 26]),
#   'Button B': array([11, 20]),
#   'Prize': array([16911, 16316])},
#  {'Button A': array([23, 57]),
#   'Button B': array([65, 24]),
#   'Prize': array([ 7618, 14318])},
#  {'Button A': array([81, 19]),
#   'Button B': array([35, 56]),
#   'Prize': array([8572, 3540])},
#  {'Button A': array([27, 61]),
#   'Button B': array([63, 22]),
#   'Prize': array([4238, 4516])},
#  {'Button A': array([35, 15]),
#   'Button B': array([64, 99]),
#   'Prize': array([4489, 5574])},
#  {'Button A': array([37, 56]),
#   'Button B': array([95, 30]),
#   'Prize': array([5412, 3526])},
#  {'Button A': array([43, 77]),
#   'Button B': array([70, 33]),
#   'Prize': array([5902, 6413])},
#  {'Button A': array([63, 24]),
#   'Button B': array([14, 63]),
#   'Prize': array([14599, 13073])},
#  {'Button A': array([17, 44]),
#   'Button B': array([55, 26]),
#   'Prize': array([3109, 1126])},
#  {'Button A': array([56, 99]),
#   'Button B': array([75, 16]),
#   'Prize': array([6353, 2487])},
#  {'Button A': array([56, 81]),
#   'Button B': array([88, 28]),
#   'Prize': array([8328, 4103])},
#  {'Button A': array([99, 59]),
#   'Button B': array([43, 95]),
#   'Prize': array([ 7598, 10078])},
#  {'Button A': array([22, 62]),
#   'Button B': array([62, 13]),
#   'Prize': array([ 7828, 14184])},
#  {'Button A': array([95, 14]),
#   'Button B': array([42, 94]),
#   'Prize': array([6248, 9614])},
#  {'Button A': array([68, 50]),
#   'Button B': array([14, 69]),
#   'Prize': array([3108, 3342])},
#  {'Button A': array([23, 13]),
#   'Button B': array([12, 30]),
#   'Prize': array([16675,  1299])},
#  {'Button A': array([97, 39]),
#   'Button B': array([13, 95]),
#   'Prize': array([5860, 3972])},
#  {'Button A': array([99, 21]),
#   'Button B': array([57, 87]),
#   'Prize': array([6249, 8367])},
#  {'Button A': array([32, 68]),
#   'Button B': array([55, 19]),
#   'Prize': array([ 5915, 15959])},
#  {'Button A': array([71, 41]),
#   'Button B': array([25, 56]),
#   'Prize': array([11725,  9873])},
#  {'Button A': array([31, 48]),
#   'Button B': array([36, 17]),
#   'Prize': array([ 337, 5629])},
#  {'Button A': array([84, 23]),
#   'Button B': array([11, 99]),
#   'Prize': array([5261, 5568])},
#  {'Button A': array([90, 11]),
#   'Button B': array([65, 89]),
#   'Prize': array([8745, 1312])},
#  {'Button A': array([25, 56]),
#   'Button B': array([53, 17]),
#   'Prize': array([ 7354, 10734])},
#  {'Button A': array([73, 19]),
#   'Button B': array([47, 89]),
#   'Prize': array([668, 788])},
#  {'Button A': array([22, 78]),
#   'Button B': array([62, 16]),
#   'Prize': array([2988, 5906])},
#  {'Button A': array([16, 72]),
#   'Button B': array([39, 11]),
#   'Prize': array([17067,  7351])},
#  {'Button A': array([15, 48]),
#   'Button B': array([48, 19]),
#   'Prize': array([11726,  1506])},
#  {'Button A': array([68, 44]),
#   'Button B': array([34, 73]),
#   'Prize': array([7854, 6867])},
#  {'Button A': array([64, 75]),
#   'Button B': array([77, 17]),
#   'Prize': array([11321,  6456])},
#  {'Button A': array([65, 27]),
#   'Button B': array([13, 76]),
#   'Prize': array([1612, 4482])},
#  {'Button A': array([12, 66]),
#   'Button B': array([16, 18]),
#   'Prize': array([2572, 7356])},
#  {'Button A': array([58, 47]),
#   'Button B': array([16, 93]),
#   'Prize': array([1410, 4424])},
#  {'Button A': array([39, 67]),
#   'Button B': array([37, 15]),
#   'Prize': array([11379, 11117])},
#  {'Button A': array([11, 62]),
#   'Button B': array([58, 20]),
#   'Prize': array([14896, 12112])},
#  {'Button A': array([59, 19]),
#   'Button B': array([22, 65]),
#   'Prize': array([2559, 8749])},
#  {'Button A': array([25, 29]),
#   'Button B': array([93, 15]),
#   'Prize': array([10571,  3253])},
#  {'Button A': array([38, 14]),
#   'Button B': array([11, 69]),
#   'Prize': array([2599, 2841])},
#  {'Button A': array([61, 35]),
#   'Button B': array([29, 59]),
#   'Prize': array([16543, 13201])},
#  {'Button A': array([92, 44]),
#   'Button B': array([32, 91]),
#   'Prize': array([ 9344, 10903])},
#  {'Button A': array([21, 56]),
#   'Button B': array([40, 11]),
#   'Prize': array([9942, 5041])},
#  {'Button A': array([15, 42]),
#   'Button B': array([44, 25]),
#   'Prize': array([ 9768, 12133])},
#  {'Button A': array([67, 12]),
#   'Button B': array([37, 35]),
#   'Prize': array([4653, 2706])},
#  {'Button A': array([21, 85]),
#   'Button B': array([85, 48]),
#   'Prize': array([8306, 5495])},
#  {'Button A': array([20, 45]),
#   'Button B': array([64, 26]),
#   'Prize': array([12772, 15383])},
#  {'Button A': array([65, 12]),
#   'Button B': array([22, 85]),
#   'Prize': array([6724, 3458])},
#  {'Button A': array([19, 41]),
#   'Button B': array([30, 14]),
#   'Prize': array([16402, 10018])},
#  {'Button A': array([17, 48]),
#   'Button B': array([48, 20]),
#   'Prize': array([13777, 12736])},
#  {'Button A': array([71, 18]),
#   'Button B': array([52, 83]),
#   'Prize': array([10961,  9202])},
#  {'Button A': array([36, 14]),
#   'Button B': array([19, 61]),
#   'Prize': array([10809, 12851])},
#  {'Button A': array([19, 15]),
#   'Button B': array([15, 68]),
#   'Prize': array([2004, 6524])},
#  {'Button A': array([69, 36]),
#   'Button B': array([30, 95]),
#   'Prize': array([5961, 9934])},
#  {'Button A': array([30, 53]),
#   'Button B': array([54, 29]),
#   'Prize': array([14246, 18565])},
#  {'Button A': array([25, 74]),
#   'Button B': array([63, 27]),
#   'Prize': array([5952, 5019])},
#  {'Button A': array([18, 52]),
#   'Button B': array([63, 36]),
#   'Prize': array([15371, 14440])},
#  {'Button A': array([17, 56]),
#   'Button B': array([68, 34]),
#   'Prize': array([17346,  5408])},
#  {'Button A': array([11, 35]),
#   'Button B': array([62, 33]),
#   'Prize': array([ 890, 4689])},
#  {'Button A': array([46, 24]),
#   'Button B': array([20, 37]),
#   'Prize': array([ 9402, 10611])},
#  {'Button A': array([92, 12]),
#   'Button B': array([36, 64]),
#   'Prize': array([9708, 4528])},
#  {'Button A': array([97, 75]),
#   'Button B': array([22, 63]),
#   'Prize': array([4335, 6939])},
#  {'Button A': array([28, 48]),
#   'Button B': array([36, 17]),
#   'Prize': array([2640, 2916])},
#  {'Button A': array([24, 65]),
#   'Button B': array([50, 16]),
#   'Prize': array([10692, 15010])},
#  {'Button A': array([28, 58]),
#   'Button B': array([25, 13]),
#   'Prize': array([18299,  9035])},
#  {'Button A': array([45, 15]),
#   'Button B': array([43, 79]),
#   'Prize': array([4024, 2182])},
#  {'Button A': array([48, 92]),
#   'Button B': array([90, 13]),
#   'Prize': array([9336, 9600])},
#  {'Button A': array([11, 85]),
#   'Button B': array([62, 14]),
#   'Prize': array([4059, 5785])},
#  {'Button A': array([12, 41]),
#   'Button B': array([23, 13]),
#   'Prize': array([11105,  1262])},
#  {'Button A': array([73, 29]),
#   'Button B': array([16, 65]),
#   'Prize': array([ 9268, 15090])},
#  {'Button A': array([55, 12]),
#   'Button B': array([43, 86]),
#   'Prize': array([ 9944, 14158])},
#  {'Button A': array([47, 67]),
#   'Button B': array([79, 36]),
#   'Prize': array([7070, 4179])},
#  {'Button A': array([57, 14]),
#   'Button B': array([25, 80]),
#   'Prize': array([5581, 6622])},
#  {'Button A': array([57, 37]),
#   'Button B': array([24, 94]),
#   'Prize': array([3456, 6086])},
#  {'Button A': array([87, 20]),
#   'Button B': array([39, 60]),
#   'Prize': array([4485, 5420])},
#  {'Button A': array([75, 16]),
#   'Button B': array([23, 83]),
#   'Prize': array([10499, 13180])},
#  {'Button A': array([37, 50]),
#   'Button B': array([48, 17]),
#   'Prize': array([6090, 4592])},
#  {'Button A': array([66, 36]),
#   'Button B': array([24, 49]),
#   'Prize': array([18632, 15872])},
#  {'Button A': array([45, 26]),
#   'Button B': array([20, 35]),
#   'Prize': array([12485, 17298])},
#  {'Button A': array([70, 13]),
#   'Button B': array([92, 99]),
#   'Prize': array([3000, 2605])},
#  {'Button A': array([56, 16]),
#   'Button B': array([12, 64]),
#   'Prize': array([ 2036, 15792])},
#  {'Button A': array([20, 12]),
#   'Button B': array([16, 35]),
#   'Prize': array([ 1412, 19297])},
#  {'Button A': array([58, 20]),
#   'Button B': array([22, 56]),
#   'Prize': array([ 7762, 11796])},
#  {'Button A': array([60, 41]),
#   'Button B': array([39, 86]),
#   'Prize': array([2973, 4821])},
#  {'Button A': array([16, 69]),
#   'Button B': array([44, 11]),
#   'Prize': array([16120, 18160])},
#  {'Button A': array([28, 65]),
#   'Button B': array([54, 21]),
#   'Prize': array([ 5684, 13076])},
#  {'Button A': array([77, 21]),
#   'Button B': array([12, 55]),
#   'Prize': array([13594,  9291])},
#  {'Button A': array([79, 76]),
#   'Button B': array([14, 72]),
#   'Prize': array([2314, 6616])},
#  {'Button A': array([17, 38]),
#   'Button B': array([56, 19]),
#   'Prize': array([5724, 2571])},
#  {'Button A': array([93, 15]),
#   'Button B': array([28, 40]),
#   'Prize': array([10183,  4765])},
#  {'Button A': array([46, 22]),
#   'Button B': array([14, 37]),
#   'Prize': array([11324,  4821])},
#  {'Button A': array([59, 60]),
#   'Button B': array([16, 88]),
#   'Prize': array([4381, 9548])},
#  {'Button A': array([28, 49]),
#   'Button B': array([53, 19]),
#   'Prize': array([ 9050, 12610])},
#  {'Button A': array([57, 19]),
#   'Button B': array([31, 61]),
#   'Prize': array([8787, 3921])},
#  {'Button A': array([98, 35]),
#   'Button B': array([29, 43]),
#   'Prize': array([11035,  6324])},
#  {'Button A': array([68, 14]),
#   'Button B': array([21, 66]),
#   'Prize': array([2087, 1178])},
#  {'Button A': array([34, 94]),
#   'Button B': array([29, 17]),
#   'Prize': array([5335, 9127])},
#  {'Button A': array([25, 90]),
#   'Button B': array([84, 54]),
#   'Prize': array([7831, 7326])},
#  {'Button A': array([38, 85]),
#   'Button B': array([57, 12]),
#   'Prize': array([ 6352, 16470])},
#  {'Button A': array([12, 37]),
#   'Button B': array([81, 57]),
#   'Prize': array([18107, 14954])},
#  {'Button A': array([13, 78]),
#   'Button B': array([89, 24]),
#   'Prize': array([1935, 4470])},
#  {'Button A': array([65, 37]),
#   'Button B': array([23, 46]),
#   'Prize': array([3654, 3495])},
#  {'Button A': array([17, 20]),
#   'Button B': array([93, 20]),
#   'Prize': array([8090, 3080])},
#  {'Button A': array([93, 30]),
#   'Button B': array([20, 28]),
#   'Prize': array([2432, 1000])},
#  {'Button A': array([71, 84]),
#   'Button B': array([52, 15]),
#   'Prize': array([7516, 5217])},
#  {'Button A': array([21, 54]),
#   'Button B': array([52, 16]),
#   'Prize': array([ 2147, 18242])},
#  {'Button A': array([39, 16]),
#   'Button B': array([18, 46]),
#   'Prize': array([1902, 3020])},
#  {'Button A': array([86, 33]),
#   'Button B': array([22, 35]),
#   'Prize': array([1794, 2335])},
#  {'Button A': array([11, 30]),
#   'Button B': array([37, 20]),
#   'Prize': array([7470,  260])},
#  {'Button A': array([16, 62]),
#   'Button B': array([58, 16]),
#   'Prize': array([18140,  7710])},
#  {'Button A': array([82, 33]),
#   'Button B': array([15, 80]),
#   'Prize': array([8467, 8363])},
#  {'Button A': array([69, 34]),
#   'Button B': array([20, 43]),
#   'Prize': array([ 3144, 18421])},
#  {'Button A': array([62, 49]),
#   'Button B': array([28, 71]),
#   'Prize': array([4712, 5239])},
#  {'Button A': array([62, 19]),
#   'Button B': array([15, 77]),
#   'Prize': array([6321, 9105])},
#  {'Button A': array([26, 60]),
#   'Button B': array([38, 18]),
#   'Prize': array([12474, 14912])},
#  {'Button A': array([70, 28]),
#   'Button B': array([33, 95]),
#   'Prize': array([4823, 9373])},
#  {'Button A': array([64, 30]),
#   'Button B': array([12, 49]),
#   'Prize': array([5508, 2749])},
#  {'Button A': array([18, 71]),
#   'Button B': array([37, 21]),
#   'Prize': array([1617, 4504])},
#  {'Button A': array([79, 21]),
#   'Button B': array([17, 69]),
#   'Prize': array([19369,  5513])},
#  {'Button A': array([30, 15]),
#   'Button B': array([20, 39]),
#   'Prize': array([16260,  9683])},
#  {'Button A': array([97, 55]),
#   'Button B': array([27, 65]),
#   'Prize': array([5856, 6600])},
#  {'Button A': array([11, 18]),
#   'Button B': array([93, 26]),
#   'Prize': array([9880, 4180])},
#  {'Button A': array([18, 47]),
#   'Button B': array([63, 22]),
#   'Prize': array([ 5318, 10167])},
#  {'Button A': array([12, 37]),
#   'Button B': array([71, 39]),
#   'Prize': array([15472,  8080])},
#  {'Button A': array([52, 11]),
#   'Button B': array([12, 43]),
#   'Prize': array([9524, 7797])},
#  {'Button A': array([14, 59]),
#   'Button B': array([68, 15]),
#   'Prize': array([9658, 2446])},
#  {'Button A': array([34, 63]),
#   'Button B': array([49, 27]),
#   'Prize': array([15893,   881])},
#  {'Button A': array([97, 52]),
#   'Button B': array([54, 89]),
#   'Prize': array([13925, 13350])},
#  {'Button A': array([13, 58]),
#   'Button B': array([85, 15]),
#   'Prize': array([6564, 6339])},
#  {'Button A': array([17, 35]),
#   'Button B': array([66, 31]),
#   'Prize': array([ 8789, 10213])},
#  {'Button A': array([78, 32]),
#   'Button B': array([25, 80]),
#   'Prize': array([7141, 7184])},
#  {'Button A': array([34, 13]),
#   'Button B': array([14, 61]),
#   'Prize': array([10584,  1026])},
#  {'Button A': array([38, 65]),
#   'Button B': array([39, 13]),
#   'Prize': array([ 5996, 16032])},
#  {'Button A': array([21, 11]),
#   'Button B': array([19, 52]),
#   'Prize': array([16972, 16513])},
#  {'Button A': array([29, 63]),
#   'Button B': array([30, 15]),
#   'Prize': array([4874, 8783])},
#  {'Button A': array([56, 21]),
#   'Button B': array([12, 63]),
#   'Prize': array([14744,   872])},
#  {'Button A': array([25, 93]),
#   'Button B': array([21, 19]),
#   'Prize': array([1514, 5100])},
#  {'Button A': array([66, 11]),
#   'Button B': array([16, 74]),
#   'Prize': array([ 8246, 18099])},
#  {'Button A': array([45, 96]),
#   'Button B': array([88, 29]),
#   'Prize': array([8599, 4376])},
#  {'Button A': array([40, 19]),
#   'Button B': array([26, 60]),
#   'Prize': array([ 4006, 15275])},
#  {'Button A': array([50, 15]),
#   'Button B': array([39, 78]),
#   'Prize': array([12516,  8927])},
#  {'Button A': array([29, 12]),
#   'Button B': array([12, 28]),
#   'Prize': array([8787, 4740])},
#  {'Button A': array([54, 11]),
#   'Button B': array([15, 50]),
#   'Prize': array([15656,  6554])},
#  {'Button A': array([78, 99]),
#   'Button B': array([97, 27]),
#   'Prize': array([10526,  5094])},
#  {'Button A': array([32, 76]),
#   'Button B': array([91, 24]),
#   'Prize': array([3316, 2496])},
#  {'Button A': array([31, 95]),
#   'Button B': array([94, 34]),
#   'Prize': array([2968, 3252])},
#  {'Button A': array([50, 80]),
#   'Button B': array([54, 21]),
#   'Prize': array([5372, 2513])},
#  {'Button A': array([85, 12]),
#   'Button B': array([47, 82]),
#   'Prize': array([8783, 4556])},
#  {'Button A': array([12, 53]),
#   'Button B': array([85, 35]),
#   'Prize': array([18387,  7483])},
#  {'Button A': array([14, 44]),
#   'Button B': array([94, 44]),
#   'Prize': array([5970, 5940])},
#  {'Button A': array([38, 26]),
#   'Button B': array([13, 41]),
#   'Prize': array([4108, 5636])},
#  {'Button A': array([51, 79]),
#   'Button B': array([77, 34]),
#   'Prize': array([6236, 2923])},
#  {'Button A': array([82, 95]),
#   'Button B': array([89, 17]),
#   'Prize': array([10900,  8667])},
#  {'Button A': array([14, 54]),
#   'Button B': array([76, 50]),
#   'Prize': array([3624, 4982])},
#  {'Button A': array([67, 12]),
#   'Button B': array([23, 83]),
#   'Prize': array([10446,  4541])},
#  {'Button A': array([24, 60]),
#   'Button B': array([63, 33]),
#   'Prize': array([17069, 15263])},
#  {'Button A': array([20, 95]),
#   'Button B': array([43, 28]),
#   'Prize': array([1916, 6986])},
#  {'Button A': array([50, 21]),
#   'Button B': array([25, 67]),
#   'Prize': array([14100, 18316])},
#  {'Button A': array([40, 13]),
#   'Button B': array([39, 59]),
#   'Prize': array([13034, 11426])},
#  {'Button A': array([38, 54]),
#   'Button B': array([33, 13]),
#   'Prize': array([ 8021, 11177])},
#  {'Button A': array([13, 54]),
#   'Button B': array([77, 13]),
#   'Prize': array([ 9827, 10690])},
#  {'Button A': array([50, 22]),
#   'Button B': array([16, 26]),
#   'Prize': array([11924,  7616])},
#  {'Button A': array([23, 58]),
#   'Button B': array([60, 27]),
#   'Prize': array([5109, 2442])},
#  {'Button A': array([38, 63]),
#   'Button B': array([44, 20]),
#   'Prize': array([ 7734, 12771])},
#  {'Button A': array([52, 76]),
#   'Button B': array([47, 20]),
#   'Prize': array([5926, 6616])},
#  {'Button A': array([24, 98]),
#   'Button B': array([73, 11]),
#   'Prize': array([5449, 8183])},
#  {'Button A': array([56, 85]),
#   'Button B': array([68, 12]),
#   'Prize': array([4252, 3079])},
#  {'Button A': array([19, 34]),
#   'Button B': array([47, 23]),
#   'Prize': array([839, 479])},
#  {'Button A': array([20, 39]),
#   'Button B': array([43, 12]),
#   'Prize': array([6796, 3395])},
#  {'Button A': array([65, 25]),
#   'Button B': array([23, 58]),
#   'Prize': array([11974, 11469])},
#  {'Button A': array([17, 52]),
#   'Button B': array([57, 17]),
#   'Prize': array([ 461, 2091])},
#  {'Button A': array([27, 53]),
#   'Button B': array([55, 29]),
#   'Prize': array([1810, 1342])},
#  {'Button A': array([24, 78]),
#   'Button B': array([68, 11]),
#   'Prize': array([7508, 1271])},
#  {'Button A': array([34, 94]),
#   'Button B': array([99, 25]),
#   'Prize': array([9055, 3397])},
#  {'Button A': array([43, 20]),
#   'Button B': array([49, 76]),
#   'Prize': array([17870,  4136])},
#  {'Button A': array([49, 16]),
#   'Button B': array([17, 29]),
#   'Prize': array([ 7755, 14760])},
#  {'Button A': array([55, 25]),
#   'Button B': array([14, 66]),
#   'Prize': array([2621, 6499])},
#  {'Button A': array([51, 58]),
#   'Button B': array([89, 24]),
#   'Prize': array([7560, 4428])},
#  {'Button A': array([34, 95]),
#   'Button B': array([52, 30]),
#   'Prize': array([4234, 7795])},
#  {'Button A': array([95, 11]),
#   'Button B': array([25, 99]),
#   'Prize': array([8155, 8921])},
#  {'Button A': array([66, 59]),
#   'Button B': array([13, 57]),
#   'Prize': array([7405, 9660])},
#  {'Button A': array([37, 54]),
#   'Button B': array([92, 18]),
#   'Prize': array([8410, 1926])},
#  {'Button A': array([14, 33]),
#   'Button B': array([56, 23]),
#   'Prize': array([8152, 4602])},
#  {'Button A': array([14, 34]),
#   'Button B': array([65, 20]),
#   'Prize': array([13444,   554])},
#  {'Button A': array([21, 54]),
#   'Button B': array([78, 20]),
#   'Prize': array([6282, 4236])},
#  {'Button A': array([40, 21]),
#   'Button B': array([13, 31]),
#   'Prize': array([3100, 5871])},
#  {'Button A': array([37, 80]),
#   'Button B': array([43, 11]),
#   'Prize': array([ 7602, 14473])},
#  {'Button A': array([86, 50]),
#   'Button B': array([20, 92]),
#   'Prize': array([5016, 7176])},
#  {'Button A': array([38, 18]),
#   'Button B': array([13, 36]),
#   'Prize': array([2274, 2808])},
#  {'Button A': array([21, 65]),
#   'Button B': array([44, 15]),
#   'Prize': array([3749, 2030])},
#  {'Button A': array([53, 15]),
#   'Button B': array([22, 53]),
#   'Prize': array([15552,  2522])},
#  {'Button A': array([72, 24]),
#   'Button B': array([25, 73]),
#   'Prize': array([15680,  2048])},
#  {'Button A': array([37, 24]),
#   'Button B': array([12, 40]),
#   'Prize': array([4607, 5920])},
#  {'Button A': array([73, 42]),
#   'Button B': array([26, 56]),
#   'Prize': array([16573, 14662])},
#  {'Button A': array([68, 21]),
#   'Button B': array([18, 58]),
#   'Prize': array([5818, 3239])},
#  {'Button A': array([16, 35]),
#   'Button B': array([72, 43]),
#   'Prize': array([6664, 6106])},
#  {'Button A': array([84, 81]),
#   'Button B': array([16, 81]),
#   'Prize': array([ 5316, 11421])},
#  {'Button A': array([29, 15]),
#   'Button B': array([27, 74]),
#   'Prize': array([2469, 2898])},
#  {'Button A': array([15, 86]),
#   'Button B': array([75, 38]),
#   'Prize': array([2955, 5574])},
#  {'Button A': array([74, 22]),
#   'Button B': array([19, 71]),
#   'Prize': array([8711, 2627])},
#  {'Button A': array([16, 30]),
#   'Button B': array([48, 29]),
#   'Prize': array([ 5232, 13215])},
#  {'Button A': array([12, 41]),
#   'Button B': array([79, 47]),
#   'Prize': array([8121, 5678])},
#  {'Button A': array([20, 37]),
#   'Button B': array([38, 21]),
#   'Prize': array([14746,  1962])},
#  {'Button A': array([35, 58]),
#   'Button B': array([80, 20]),
#   'Prize': array([3555, 1726])},
#  {'Button A': array([59, 16]),
#   'Button B': array([13, 71]),
#   'Prize': array([8034, 5167])},
#  {'Button A': array([22, 56]),
#   'Button B': array([73, 21]),
#   'Prize': array([8784, 7196])},
#  {'Button A': array([73, 12]),
#   'Button B': array([25, 31]),
#   'Prize': array([3979, 3128])},
#  {'Button A': array([72, 70]),
#   'Button B': array([11, 40]),
#   'Prize': array([7193, 9660])},
#  {'Button A': array([41, 18]),
#   'Button B': array([30, 49]),
#   'Prize': array([16627,  2420])},
#  {'Button A': array([51, 15]),
#   'Button B': array([11, 24]),
#   'Prize': array([4579, 1301])},
#  {'Button A': array([50, 37]),
#   'Button B': array([24, 56]),
#   'Prize': array([3574, 3639])},
#  {'Button A': array([17, 34]),
#   'Button B': array([52, 18]),
#   'Prize': array([ 2105, 15858])},
#  {'Button A': array([40, 74]),
#   'Button B': array([98, 38]),
#   'Prize': array([1540, 1416])},
#  {'Button A': array([80, 13]),
#   'Button B': array([41, 76]),
#   'Prize': array([5729, 7102])},
#  {'Button A': array([18, 53]),
#   'Button B': array([64, 12]),
#   'Prize': array([18926,  2619])},
#  {'Button A': array([28, 82]),
#   'Button B': array([72, 12]),
#   'Prize': array([7592, 3740])},
#  {'Button A': array([46, 17]),
#   'Button B': array([39, 61]),
#   'Prize': array([11153,  7031])},
#  {'Button A': array([88, 46]),
#   'Button B': array([43, 88]),
#   'Prize': array([7711, 9076])},
#  {'Button A': array([97, 60]),
#   'Button B': array([33, 99]),
#   'Prize': array([6934, 6018])},
#  {'Button A': array([30, 13]),
#   'Button B': array([51, 70]),
#   'Prize': array([5096,  903])},
#  {'Button A': array([80, 40]),
#   'Button B': array([13, 48]),
#   'Prize': array([5087, 3712])},
#  {'Button A': array([81, 43]),
#   'Button B': array([38, 79]),
#   'Prize': array([4714, 4032])},
#  {'Button A': array([43, 17]),
#   'Button B': array([22, 34]),
#   'Prize': array([10335,  2029])},
#  {'Button A': array([35, 15]),
#   'Button B': array([37, 60]),
#   'Prize': array([18072, 16940])},
#  {'Button A': array([56, 17]),
#   'Button B': array([17, 47]),
#   'Prize': array([ 5477, 17402])},
#  {'Button A': array([49, 24]),
#   'Button B': array([11, 32]),
#   'Prize': array([16331, 13400])},
#  {'Button A': array([78, 82]),
#   'Button B': array([88, 19]),
#   'Prize': array([4818, 1757])},
#  {'Button A': array([51, 11]),
#   'Button B': array([17, 39]),
#   'Prize': array([16088, 11070])},
#  {'Button A': array([43, 25]),
#   'Button B': array([29, 56]),
#   'Prize': array([11532,  3270])},
#  {'Button A': array([97, 23]),
#   'Button B': array([94, 92]),
#   'Prize': array([16932,  9522])},
#  {'Button A': array([61, 24]),
#   'Button B': array([11, 30]),
#   'Prize': array([18123, 18320])},
#  {'Button A': array([20, 38]),
#   'Button B': array([32, 14]),
#   'Prize': array([17300,  7256])},
#  {'Button A': array([22, 80]),
#   'Button B': array([82, 16]),
#   'Prize': array([444, 768])},
#  {'Button A': array([12, 61]),
#   'Button B': array([77, 23]),
#   'Prize': array([18198,  3897])},
#  {'Button A': array([13, 93]),
#   'Button B': array([72, 50]),
#   'Prize': array([2887, 7631])},
#  {'Button A': array([57, 20]),
#   'Button B': array([19, 44]),
#   'Prize': array([11615,  3772])},
#  {'Button A': array([29, 55]),
#   'Button B': array([47, 20]),
#   'Prize': array([13874,  2240])},
#  {'Button A': array([56, 32]),
#   'Button B': array([16, 30]),
#   'Prize': array([5560, 3782])},
#  {'Button A': array([47, 15]),
#   'Button B': array([18, 41]),
#   'Prize': array([15886,  6408])},
#  {'Button A': array([31, 67]),
#   'Button B': array([46, 17]),
#   'Prize': array([3716, 4817])},
#  {'Button A': array([38, 13]),
#   'Button B': array([54, 76]),
#   'Prize': array([6854, 9010])},
#  {'Button A': array([19, 60]),
#   'Button B': array([49, 12]),
#   'Prize': array([7644, 5576])},
#  {'Button A': array([61, 18]),
#   'Button B': array([14, 54]),
#   'Prize': array([11432,  9926])},
#  {'Button A': array([14, 56]),
#   'Button B': array([36, 17]),
#   'Prize': array([14644, 14881])},
#  {'Button A': array([60, 21]),
#   'Button B': array([19, 47]),
#   'Prize': array([  959, 13763])},
#  {'Button A': array([64, 15]),
#   'Button B': array([16, 69]),
#   'Prize': array([11312,  8135])},
#  {'Button A': array([13, 55]),
#   'Button B': array([81, 31]),
#   'Prize': array([ 4965, 10539])},
#  {'Button A': array([12, 57]),
#   'Button B': array([79, 12]),
#   'Prize': array([13806, 19367])},
#  {'Button A': array([31, 21]),
#   'Button B': array([16, 47]),
#   'Prize': array([3046, 4884])},
#  {'Button A': array([69, 34]),
#   'Button B': array([18, 90]),
#   'Prize': array([2625, 9082])},
#  {'Button A': array([11, 91]),
#   'Button B': array([94, 43]),
#   'Prize': array([6738, 6521])},
#  {'Button A': array([42, 64]),
#   'Button B': array([41, 17]),
#   'Prize': array([14992, 19084])},
#  {'Button A': array([26, 56]),
#   'Button B': array([55, 14]),
#   'Prize': array([ 9439, 19758])},
#  {'Button A': array([31, 11]),
#   'Button B': array([12, 49]),
#   'Prize': array([12096,   439])},
#  {'Button A': array([36, 13]),
#   'Button B': array([15, 94]),
#   'Prize': array([1818, 1188])},
#  {'Button A': array([64, 13]),
#   'Button B': array([43, 97]),
#   'Prize': array([5574, 2721])},
#  {'Button A': array([49, 35]),
#   'Button B': array([39, 97]),
#   'Prize': array([6430, 7566])},
#  {'Button A': array([18, 78]),
#   'Button B': array([36, 18]),
#   'Prize': array([3078, 6714])},
#  {'Button A': array([12, 30]),
#   'Button B': array([56, 33]),
#   'Prize': array([18052,  7343])},
#  {'Button A': array([22, 70]),
#   'Button B': array([39, 11]),
#   'Prize': array([ 2986, 12450])},
#  {'Button A': array([14, 59]),
#   'Button B': array([73, 16]),
#   'Prize': array([5132, 5489])},
#  {'Button A': array([49, 16]),
#   'Button B': array([41, 68]),
#   'Prize': array([2601,  564])},
#  {'Button A': array([63, 90]),
#   'Button B': array([84, 11]),
#   'Prize': array([12810,  8054])},
#  {'Button A': array([41, 14]),
#   'Button B': array([27, 52]),
#   'Prize': array([ 2989, 18458])},
#  {'Button A': array([20, 96]),
#   'Button B': array([78, 22]),
#   'Prize': array([3298, 8430])},
#  {'Button A': array([33, 80]),
#   'Button B': array([56, 15]),
#   'Prize': array([4260, 5980])},
#  {'Button A': array([76, 16]),
#   'Button B': array([14, 81]),
#   'Prize': array([4602, 7135])},
#  {'Button A': array([49, 20]),
#   'Button B': array([18, 73]),
#   'Prize': array([3478, 2667])},
#  {'Button A': array([42, 44]),
#   'Button B': array([17, 96]),
#   'Prize': array([3420, 4052])},
#  {'Button A': array([11, 59]),
#   'Button B': array([58, 26]),
#   'Prize': array([7683, 7795])},
#  {'Button A': array([85, 48]),
#   'Button B': array([13, 86]),
#   'Prize': array([8681, 7026])},
#  {'Button A': array([18, 61]),
#   'Button B': array([43, 14]),
#   'Prize': array([ 9307, 14925])},
#  {'Button A': array([31, 54]),
#   'Button B': array([33, 16]),
#   'Prize': array([11353,   508])}]

# %%
import tqdm

# %%
def calculate_minimal_tokens(machine):
    options = []
    for n_buttons in range(1, 201):
        tokens_a_min = max(n_buttons - 100, 0)
        tokens_a_max = min(n_buttons, 100)
        for buttons_a in range(tokens_a_min, tokens_a_max + 1):
            buttons_b = n_buttons - buttons_a
            total = buttons_a * machine["Button A"] + buttons_b * machine["Button B"]
            if (total == machine["Prize"]).all():
                options.append((buttons_a, buttons_b))
    if options:
        if len(options) > 2:
            print(options)
        costs = [buttons_a * 3 + buttons_b for buttons_a, buttons_b in options]
        return min(costs)

    return 0


total_costs = [calculate_minimal_tokens(machine) for machine in tqdm.tqdm(parsed_data)]
# Out:
#   0%|          | 0/320 [00:00<?, ?it/s]
# 100%|██████████| 320/320 [00:15<00:00, 20.40it/s]

# %%
sum(total_costs)
# Out:
# 33427

# %% [markdown]
# # Part 2

# %%
10000000018641 / 10000000010279
# Out:
# 0.38028169014084506

# %%
# x * 69/23 + (1-x) * 27 / 71 = 10000000018641 / 10000000010279

(10000000018641 / 10000000010279 - 27 / 71) / (69 / 23 - 27 / 71)
# Out:
# 0.2365591401041409

# %%
69 / 23
27 / 71
# Out:
# 0.38028169014084506

# %%
67 * 26
# Out:
# 1742
